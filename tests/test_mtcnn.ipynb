# %%
import sys
sys.path.append("/opt/ml/canvas-mofy")

# %%
from PIL import Image

image = Image.open("/opt/ml/canvas-mofy/.assets/sample_input/dest_images/kakao2.jpg")

print(image)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F086E0DB280>
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>

# %%
image = image.convert("RGB")

# %%
print(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F367C6694C0>

# %%
from face_detection.mtcnn import MTCNN
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

net = MTCNN(keep_all=True)
image = image
bboxes, probs = net.detect(image)
print(bboxes)
# Out:
# /opt/ml/canvas-mofy/face_detection/mtcnn/mtcnn_utils.py:213: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /tmp/pip-req-build-ojg3q6e4/torch/csrc/utils/python_arg_parser.cpp:882.)
#   mask_inds = mask.nonzero()
# [[-35.202354 214.45078   83.62257  357.05927 ]
#  [232.17708  132.17311  286.45978  208.98897 ]
#  [529.63715   91.18544  569.4054   140.11166 ]
#  [470.9075   124.6627   509.2153   173.39203 ]
#  [261.99448   75.96329  293.51108  117.60716 ]
#  [398.25595  124.51171  431.25574  162.34073 ]
#  [  4.2783    85.626274  36.17579  123.074455]
#  [136.26358  118.85752  166.04416  154.87968 ]
#  [ 45.792477  94.45823   69.96595  124.17582 ]
#  [470.7639    94.337654 494.12512  124.198296]
#  [233.2897    91.14293  251.42075  113.21696 ]
#  [353.07898  101.406975 369.8849   124.18083 ]]
