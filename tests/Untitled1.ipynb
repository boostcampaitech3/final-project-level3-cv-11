# %%
import sys
sys.path.append("/opt/ml/canvas-mofy/")

# %%
from face_detection.yolov5_face import load_yolov5

# %%
str(sys.path[-1])
# Out:
# '/opt/ml/canvas-mofy/face_detection/yolov5_face'

# %%
# !pip -qq install thop

# %%
import torch
model = load_yolov5("/opt/ml/canvas-mofy/.assets/model_weights/detector/yolov5_face/yolov5n-face.pt", torch.device('cuda:0' if torch.cuda.is_available() else 'cpu'))
# Out:
# Fusing layers...

# %%
model
# Out:
# Model(
#   (model): Sequential(
#     (0): StemBlock(
#       (stem_1): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (stem_2a): Conv(
#         (conv): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(8, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (stem_2b): Conv(
#         (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (stem_2p): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (stem_3): Conv(
# ...
